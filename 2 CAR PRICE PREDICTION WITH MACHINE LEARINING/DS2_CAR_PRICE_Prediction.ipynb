# %% [markdown]
# **TASK 2 :**

# %% [markdown]
# # **🚗 CAR PRICE Prediction with MACHINE LEARNING.**

# %% [markdown]
# ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Car price prediction in machine learning is a task where algorithms use historical data on car attributes (e.g., make, model, year, mileage, features) to predict the future selling price of a car. This helps buyers and sellers estimate a fair price, leveraging mathematical models and techniques like regression to make accurate predictions.
#
#
# ---
# INPUT TO THE MODEL :
# 1. Fuel Type
# 2. Driver Wheel
# 3. Car Width
# 4. Engine Type, etc.
#
# OUTPUT FROM THE MODEL :
# Predicted Car Price: The estimated selling price of the car based on the input features and historical data.
#
#
# ---
#
#
#
# ---

# %% [markdown]
# **IMPORTING LIBRARIES :**
# 1.   NumPy
# 2.   Pandas
# 3.   Matplotlib
# 4.   Seaborn

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mplot

# %% [markdown]
# ---

# %% [markdown]
# 📄 IMPORTING DATASET :

# %%
dataset = pd.read_csv('car_dataset.csv')
dataset.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# SHAPE OF DATASET :

# %%
dataset.shape

print("Total Number of ROW's : ", dataset.shape[0])
print("Total Number of COLUMN's : ", dataset.shape[1])
# Out:
# Total Number of ROW's :  205
# Total Number of COLUMN's :  26

# %% [markdown]
# INFORMATION ABOUT DATASET :

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# CHECKING Is there any NULL Values :

# %%
dataset.isnull()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0     False      False    False     False       False       False    False
# 1     False      False    False     False       False       False    False
# 2     False      False    False     False       False       False    False
# 3     False      False    False     False       False       False    False
# 4     False      False    False     False       False       False    False
# ..      ...        ...      ...       ...         ...         ...      ...
# 200   False      False    False     False       False       False    False
# 201   False      False    False     False       False       False    False
# 202   False      False    False     False       False       False    False
# 203   False      False    False     False       False       False    False
# 204   False      False    False     False       False       False    False
#
# ...

# %%
dataset.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# OVERALL STATISTICS ABOUT DATASET :

# %%
dataset.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **VISUALIZATION OF DATASET**
#
# Visualization of a dataset helps to uncover patterns, trends, and outliers quickly, enhancing data understanding and aiding in better decision-making. It makes complex data more accessible and interpretable.

# %% [markdown]
# # **OUTLIER REMOVAL :**

# %%
sb.boxenplot(dataset['price'])
# Out:
# <Axes: >

# %% [markdown]
# Now, we can see 1 value is Varrying drastically. So it will be better to not take it into consideratio. otherwise it will make impact on mean, deviation and etc, parameters.

# %%
sorted(dataset['price'],reverse=True)[:10]
# Out:
# [45400.0,
#  41315.0,
#  40960.0,
#  37028.0,
#  36880.0,
#  36000.0,
#  35550.0,
#  35056.0,
#  34184.0,
#  34028.0]

# %%
dataset[(dataset['price']>45000)]
# Out:
#     car_ID  symboling                          CarName fueltype aspiration  \
# 74      75          1  buick regal sport coupe (turbo)      gas        std
#
#    doornumber  carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 74        two  hardtop        rwd          front      112.0  ...         304
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 74        mpfi        3.8    3.35              8.0        184     4500
#
#    citympg  highwaympg    price
# 74      14          16  45400.0
#
# [1 rows x 26 columns]
# ...

# %% [markdown]
# Going to remove this OUTIER :

# %%
dataset=dataset[~(dataset['price']>45000)]

# %% [markdown]
# Removedd..

# %% [markdown]
# Previously shape was (205,26). Current should be (204,26).

# %%
dataset.shape

print("Total Number of ROW's : ", dataset.shape[0])
print("Total Number of COLUMN's : ", dataset.shape[1])
# Out:
# Total Number of ROW's :  204
# Total Number of COLUMN's :  26

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # **ENCODING THE CATEGORICAL COLUMNS :**
# Encoding categorical columns is essential in machine learning as it transforms non-numeric data into a format that algorithms can understand, enabling the utilization of categorical information for modeling and improving prediction accuracy.

# %%
dataset.head(1)
# Out:
#    car_ID  symboling             CarName fueltype aspiration doornumber  \
# 0       1          3  alfa-romero giulia      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
#
#    highwaympg    price
# 0          27  13495.0
#
# [1 rows x 26 columns]
# ...

# %% [markdown]
# CATEGORICAL COLUMNS : fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, enginetype, cylindernumber,fulesystem.

# %% [markdown]
# Machine Learning algorithms can only understant NUMERICAL VALUES, not CATEGORICAL VALUES. (CATEGORICAL VALUES : String type Values)
#
# We need to convert those Categorical Values to Some NUMERIC VALUES.

# %% [markdown]
# 1. fueltype Column :

# %%
dataset['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
dataset['fueltype']=dataset['fueltype'].map({'gas':0, 'diesel':1})

# %%
dataset['fueltype'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# 2. aspiration COLUMN :

# %%
dataset['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
dataset['aspiration'] = dataset['aspiration'].map({'std':0, 'turbo':1})

# %%
dataset['aspiration'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# 3. doornumber COLUMN :

# %%
dataset['doornumber'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
dataset['doornumber'] = dataset['doornumber'].map({'two':0, 'four':1})

# %%
dataset['doornumber'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# 4. carbody COLUMN :

# %%
dataset['carbody'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
dataset['carbody'] = dataset['carbody'].map({'convertible':0, 'hatchback':1, 'sedan':2, 'wagon':3, 'hardtop':4})

# %%
dataset['carbody'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# 5. drivewheel COLUMN :

# %%
dataset['drivewheel'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
dataset['drivewheel'] = dataset['drivewheel'].map({'rwd':0, 'fwd':1, '4wd':2})

# %%
dataset['drivewheel'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# 6. enginelocation COLUMN :

# %%
dataset['enginelocation'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
dataset['enginelocation'] = dataset['enginelocation'].map({'front':0, 'rear':1})

# %%
dataset['enginelocation'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# 7. enginetype COLUMN :

# %%
dataset['enginetype'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
dataset['enginetype'] = dataset['enginetype'].map({'dohc':0, 'ohcv':1, 'ohc':2, 'l':3, 'rotor':4, 'ohcf':5, 'dohcv':6})

# %%
dataset['enginetype'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %% [markdown]
# 8. 	cylindernumber COLUMN :

# %%
dataset['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
dataset['cylindernumber'] = dataset['cylindernumber'].map({'four':0, 'six':1, 'five':2, 'three':3, 'twelve':4, 'two':5, 'eight':6})

# %%
dataset['cylindernumber'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %% [markdown]
# 9. fuelsystem COLUMN :

# %%
dataset['fuelsystem'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
dataset['fuelsystem'] = dataset['fuelsystem'].map({'mpfi':0, '2bbl':1, 'mfi':2, '1bbl':3, 'spfi':4, '4bbl':5, 'idi':6, 'spdi':7})

# %%
dataset['fuelsystem'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# **CHECKING AGAIN FOR CATEGORIAL COLUMN :**

# %%
dataset.head()
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         0           0
# 1       2          3       alfa-romero stelvio         0           0
# 2       3          1  alfa-romero Quadrifoglio         0           0
# 3       4          2               audi 100 ls         0           0
# 4       5          2                audi 100ls         0           0
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           0        0           0               0       88.6  ...
# 1           0        0           0               0       88.6  ...
# 2           0        1           0               0       94.5  ...
# 3           1        2           1               0       99.8  ...
# 4           1        2           2               0       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
dataset.tail()
# Out:
#      car_ID  symboling          CarName  fueltype  aspiration  doornumber  \
# 200     201         -1  volvo 145e (sw)         0           0           1
# 201     202         -1      volvo 144ea         0           1           1
# 202     203         -1      volvo 244dl         0           0           1
# 203     204         -1        volvo 246         1           1           1
# 204     205         -1      volvo 264gl         0           1           1
#
#      carbody  drivewheel  enginelocation  wheelbase  ...  enginesize  \
# 200        2           0               0      109.1  ...         141
# 201        2           0               0      109.1  ...         141
# 202        2           0               0      109.1  ...         173
# 203        2           0               0      109.1  ...         145
# 204        2           0               0      109.1  ...         141
#
#      fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# **STORE FEATURE MATRIX (INPUT COLUMNS) & RESPONSE(TARGET)(ACTUAL OUTPUT) :**
#
# Storing the feature matrix (input columns) and response (actual output) separately is crucial for training and evaluating machine learning models, as it allows for clear separation of input data and target values, enabling effective model training and assessment of predictive accuracy.

# %%
print(dataset['CarName'].unique())
# Out:
# ['alfa-romero giulia' 'alfa-romero stelvio' 'alfa-romero Quadrifoglio'
#  'audi 100 ls' 'audi 100ls' 'audi fox' 'audi 5000' 'audi 4000'
#  'audi 5000s (diesel)' 'bmw 320i' 'bmw x1' 'bmw x3' 'bmw z4' 'bmw x4'
#  'bmw x5' 'chevrolet impala' 'chevrolet monte carlo' 'chevrolet vega 2300'
#  'dodge rampage' 'dodge challenger se' 'dodge d200' 'dodge monaco (sw)'
#  'dodge colt hardtop' 'dodge colt (sw)' 'dodge coronet custom'
#  'dodge dart custom' 'dodge coronet custom (sw)' 'honda civic'
#  'honda civic cvcc' 'honda accord cvcc' 'honda accord lx'
#  'honda civic 1500 gl' 'honda accord' 'honda civic 1300' 'honda prelude'
#  'honda civic (auto)' 'isuzu MU-X' 'isuzu D-Max ' 'isuzu D-Max V-Cross'
#  'jaguar xj' 'jaguar xf' 'jaguar xk' 'maxda rx3' 'maxda glc deluxe'
#  'mazda rx2 coupe' 'mazda rx-4' 'mazda glc deluxe' 'mazda 626' 'mazda glc'
#  'mazda rx-7 gs' 'mazda glc 4' 'mazda glc custom l' 'mazda glc custom'
#  'buick electra 225 custom' 'buick century luxus (sw)' 'buick century'
# ...

# %%
input = dataset.drop(['CarName','price'], axis=1)
output = dataset['price']

# print(input)
print(output)
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 204, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# **SPLITTING DATASET INTO TRAINING & TESTING SETS :**
#
# Splitting the dataset into training and testing sets is vital for assessing a machine learning model's performance. It helps gauge how well the model generalizes to new, unseen data, preventing overfitting and ensuring reliable predictions.

# %%
from sklearn.model_selection import train_test_split
inputTRAIN, inputTEST, outputTRAIN, outputTEST = train_test_split(input, output, test_size=0.2)

# %%
# print(inputTRAIN)
# print(outputTRAIN)
# print(inputTEST)
# print(outputTEST)

# %% [markdown]
# ---

# %% [markdown]
# # **MODEL**

# %%
dataset.head()
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         0           0
# 1       2          3       alfa-romero stelvio         0           0
# 2       3          1  alfa-romero Quadrifoglio         0           0
# 3       4          2               audi 100 ls         0           0
# 4       5          2                audi 100ls         0           0
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           0        0           0               0       88.6  ...
# 1           0        0           0               0       88.6  ...
# 2           0        1           0               0       94.5  ...
# 3           1        2           1               0       99.8  ...
# 4           1        2           2               0       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %% [markdown]
# As TARGET COLUMN CONTAIN A CONTINUES VALUES :=> THIS IS A REGRESSION PROBLEM .

# %% [markdown]
# **IMPORTING REGRESSION MODELS : **

# %% [markdown]
# 1. LiearRegression
# 2. RandomForestRegressor
# 3. GradientBoostingRegressor
# 4. XGBRegressor

# %% [markdown]
# IMPORTING ALGORITHMS FROM LIBRARIES :

# %%
 from sklearn.linear_model import LinearRegression
 from sklearn.ensemble import RandomForestRegressor
 from sklearn.ensemble import GradientBoostingRegressor
 from xgboost import XGBRegressor

# %% [markdown]
# **TRAINNING TO THE MODELS :**

# %%
# TRAINNING LinearRegression MODEL :
LR_Model = LinearRegression()
LR_Model.fit(inputTRAIN, outputTRAIN)

# TRAINNING RandomForestRegressor MODEL :
RFR_Model = RandomForestRegressor()
RFR_Model.fit(inputTRAIN, outputTRAIN)

# TRAINNING GradientBoostingRegressor MODEL :
GBR_Model = GradientBoostingRegressor()
GBR_Model.fit(inputTRAIN, outputTRAIN)

# TRAINNING XGBRegressor MODEL :
XGBR_Model = XGBRegressor()
XGBR_Model.fit(inputTRAIN, outputTRAIN)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# **PREDICTING OUTPUT OF ALL MODELS :**

# %%
LR_Prediction = LR_Model.predict(inputTEST)
RFR_Prediction = RFR_Model.predict(inputTEST)
GBR_Prediction = GBR_Model.predict(inputTEST)
XGBR_Prediction = XGBR_Model.predict(inputTEST)

# %% [markdown]
# **ACCURACY SCORES OF EACH MODEL :**

# %%
from sklearn import metrics

# %% [markdown]
# 1) LinearRegression :

# %%
LR_Score = metrics.r2_score(outputTEST,LR_Prediction)*100
print("LinearRegression ACCURECY : ",LR_Score)
# Out:
# LinearRegression ACCURECY :  90.4147672045177

# %% [markdown]
# 2) RandomForestRegressor :

# %%
RFR_Score = metrics.r2_score(outputTEST,RFR_Prediction)*100
print("RandomForestRegressor ACCURECY : ",RFR_Score)
# Out:
# RandomForestRegressor ACCURECY :  93.48123483092003

# %% [markdown]
# 3) GradientBoostingRegressor :

# %%
GBR_Score = metrics.r2_score(outputTEST,GBR_Prediction)*100
print("GradientBoostingRegressor ACCURECY : ",GBR_Score)
# Out:
# GradientBoostingRegressor ACCURECY :  94.2386868433122

# %% [markdown]
# 4) XGBRegressor :

# %%
XGBR_Score = metrics.r2_score(outputTEST,XGBR_Prediction)*100
print("XGBRegressor ACCURECY : ",XGBR_Score)
# Out:
# XGBRegressor ACCURECY :  93.60303923747718

# %% [markdown]
# ---

# %% [markdown]
# # **OVERALL COMARISON BETWEEN ALGORITHMS :**

# %%
comparison = pd.DataFrame({'MODELS': ['LinearRegression','RandomForestRegressor','GradientBoostingRegressor','XGBRegressor'],
                           'R2 SCORE': [LR_Score, RFR_Score, GBR_Score, XGBR_Score]})

# %%
comparison
# Out:
#                       MODELS   R2 SCORE
# 0           LinearRegression  90.414767
# 1      RandomForestRegressor  93.481235
# 2  GradientBoostingRegressor  94.238687
# 3               XGBRegressor  93.603039

# %% [markdown]
# ---
#
# # ***THANK YOU !***
