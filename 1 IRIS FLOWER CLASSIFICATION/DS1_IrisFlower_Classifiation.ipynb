# %% [markdown]
# **TASK 1:**

# %% [markdown]
# # **🌸 IRIS FLOWER Classification using MACHINE LEARNING.**

# %% [markdown]
# ![51518iris img1.png](data:image/png;base64,...)

# %% [markdown]
# Iris flower classification in machine learning is a popular introductory classification problem. It involves training a model to categorize iris flowers into one of three species (setosa, versicolor, or virginica) based on their petal and sepal measurements. It's often used as a beginner's example to teach the fundamentals of supervised machine learning and classification algorithms.

# %% [markdown]
# ---
# INPUT TO THE MODEL :
# 1. Sepal length (in centimeters)
# 2. Sepal width (in centimeters)
# 3. Petal length (in centimeters)
# 4. Petal width (in centimeters)
#
#
# OUTPUT FROM THE MODEL :
#
# Predicted IrisFlower Species (setosa, versicolor, or virginica) based on the input features.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **IMPORTING LIBRARIES :**
# 1.   NumPy
# 2.   Pandas
# 3.   Matplotlib
# 4.   Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mplot
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# 📄 IMPORTING DATASET :

# %%
columns =  ["ID","SepalLengthCm	","SepalWidthCm","PetalLengthCm	","PetalWidthCm","SPECIES"]

#LOADING DATA :
dataset=pd.read_csv('iris_dataset.csv',names=columns)
dataset.head()
# Out:
#    ID  SepalLengthCm\t  SepalWidthCm  PetalLengthCm\t  PetalWidthCm  \
# 0   1              5.1           3.5              1.4           0.2
# 1   2              4.9           3.0              1.4           0.2
# 2   3              4.7           3.2              1.3           0.2
# 3   4              4.6           3.1              1.5           0.2
# 4   5              5.0           3.6              1.4           0.2
#
#        SPECIES
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
dataset.describe()
# Out:
#                ID  SepalLengthCm\t  SepalWidthCm  PetalLengthCm\t  \
# count  150.000000       150.000000    150.000000       150.000000
# mean    75.500000         5.843333      3.054000         3.758667
# std     43.445368         0.828066      0.433594         1.764420
# min      1.000000         4.300000      2.000000         1.000000
# 25%     38.250000         5.100000      2.800000         1.600000
# 50%     75.500000         5.800000      3.000000         4.350000
# 75%    112.750000         6.400000      3.300000         5.100000
# max    150.000000         7.900000      4.400000         6.900000
#
#        PetalWidthCm
# count    150.000000
# mean       1.198667
# std        0.763161
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000

# %% [markdown]
# ---

# %% [markdown]
# **VISUALIZATION OF DATASET**
#
# Visualization of the dataset is important as it provides a clear and intuitive way to explore patterns, relationships, and outliers in the data, aiding in better understanding and making informed decisions in data analysis and modeling.

# %%
sns.pairplot(dataset, hue='SPECIES')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 9 (	) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ---

# %% [markdown]
# **SEPERATING DATASET INPUT COLUMNS & OUTPUT COLUMN (SPECIES) :**
#
# Separating dataset input columns (features) from the output column (target variable, e.g., species) is essential for preparing data for machine learning models, enabling the model to learn patterns and make predictions effectively.

# %%
data = dataset.values

input = data[:,1:5]
output = data[:,5]

print(input)
print(output)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %% [markdown]
# ---

# %% [markdown]
# **SLITTING DATASET INTO TRAINING & TESTING :**
#
# Splitting a dataset into training and testing sets is crucial to assess how well a machine learning model generalizes to new, unseen data, helping to evaluate its performance and avoid overfitting.

# %%
from sklearn.model_selection import train_test_split
inputTRAIN, inputTEST, outputTRAIN, outputTEST = train_test_split(input, output, test_size=0.2)
print("Sr.No."+"\t"+"input TRAIN Data"+"\t"+"output TRAIN Data")
for i in range (len(inputTRAIN)):
  print(i+1,"\t",inputTRAIN[i],"\t",outputTRAIN[i])
print("-------------------------------------------------------")
print("\nSr.No."+"\t"+"input TEST Data"+"\t"+"output TEST Data")
for i in range (len(inputTEST)):
  print(i+1,"\t",inputTEST[i],"\t",outputTEST[i])
# Out:
# Sr.No.	input TRAIN Data	output TRAIN Data
# 1 	 [5.5 2.4 3.7 1.0] 	 Iris-versicolor
# 2 	 [7.0 3.2 4.7 1.4] 	 Iris-versicolor
# 3 	 [5.3 3.7 1.5 0.2] 	 Iris-setosa
# 4 	 [5.7 2.8 4.5 1.3] 	 Iris-versicolor
# 5 	 [7.7 3.0 6.1 2.3] 	 Iris-virginica
# 6 	 [4.4 2.9 1.4 0.2] 	 Iris-setosa
# 7 	 [7.7 3.8 6.7 2.2] 	 Iris-virginica
# 8 	 [5.1 3.8 1.6 0.2] 	 Iris-setosa
# 9 	 [4.7 3.2 1.3 0.2] 	 Iris-setosa
# 10 	 [4.6 3.2 1.4 0.2] 	 Iris-setosa
# 11 	 [6.3 3.3 4.7 1.6] 	 Iris-versicolor
# 12 	 [7.1 3.0 5.9 2.1] 	 Iris-virginica
# 13 	 [6.3 3.4 5.6 2.4] 	 Iris-virginica
# 14 	 [5.0 2.3 3.3 1.0] 	 Iris-versicolor
# 15 	 [5.0 3.3 1.4 0.2] 	 Iris-setosa
# 16 	 [5.4 3.7 1.5 0.2] 	 Iris-setosa
# 17 	 [5.5 2.3 4.0 1.3] 	 Iris-versicolor
# 18 	 [5.4 3.4 1.5 0.4] 	 Iris-setosa
# 19 	 [5.7 3.0 4.2 1.2] 	 Iris-versicolor
# 20 	 [5.7 2.6 3.5 1.0] 	 Iris-versicolor
# 21 	 [6.3 2.9 5.6 1.8] 	 Iris-virginica
# 22 	 [5.8 2.8 5.1 2.4] 	 Iris-virginica
# 23 	 [5.8 2.6 4.0 1.2] 	 Iris-versicolor
# ...

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# IMPORTING LIBRARY WHICH CALCULATE ACCURACY :

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ---

# %% [markdown]
# # **MODEL'S :**

# %% [markdown]
# **1) LOGISTIC REGRESSION :**

# %%
# IMPORTING Logistic Regression :
from sklearn.linear_model import LogisticRegression

LR_Algorithm=LogisticRegression()

# TRAINING TO MODEL :
LR_Algorithm.fit(inputTRAIN,outputTRAIN)
# Out:
# LogisticRegression()

# %% [markdown]
# PREDICTING THE RESULTS :

# %%
LR_Prediction = LR_Algorithm.predict(inputTEST)

# %% [markdown]
# ACCURACY OF LogisticRegression :

# %%
SCORE_1 = accuracy_score(outputTEST,LR_Prediction)*100
print(SCORE_1)
# Out:
# 93.33333333333333

# %% [markdown]
# WHAT ARE ERRORS IN TESTING (IF PRESET) :

# %%
for i in range (len(inputTEST)):
  if (LR_Prediction[i]!=outputTEST[i]):
    print(i+1," ERROR !!")
    print("Predicted Result : ",LR_Prediction[i])
    print("Actual Result : ",outputTEST[i])
# Out:
# 9  ERROR !!
# Predicted Result :  Iris-versicolor
# Actual Result :  Iris-virginica
# 29  ERROR !!
# Predicted Result :  Iris-virginica
# Actual Result :  Iris-versicolor

# %% [markdown]
# ---

# %% [markdown]
# **2) SUPPORT VECTOR CLASSIFIER :**

# %%
# IMPORTING Support Vector Classifier (SVC) :
from sklearn.svm import SVC

SVC_Algorithm=SVC()
# TRAINING TO MODEL :
SVC_Algorithm.fit(inputTRAIN,outputTRAIN)
# Out:
# SVC()

# %% [markdown]
# PREDICTING THE RESULTS :

# %%
SVC_Prediction = SVC_Algorithm.predict(inputTEST)

# %% [markdown]
# ACCURACY OF SupportVectorClassifier :

# %%
SCORE_2 = accuracy_score(outputTEST,SVC_Prediction)*100
print(SCORE_2)
# Out:
# 96.66666666666667

# %% [markdown]
# WHAT ARE ERRORS IN TESTING (IF PRESET) :

# %%
for i in range (len(inputTEST)):
  if (SVC_Prediction[i]!=outputTEST[i]):
    print(i+1," ERROR !!")
    print("Predicted Result : ",SVC_Prediction[i],"\n","Actual Result : ",outputTEST[i])
# Out:
# 29  ERROR !!
# Predicted Result :  Iris-virginica
#  Actual Result :  Iris-versicolor

# %% [markdown]
# ---

# %% [markdown]
# **3) DECISION TREE CLASSIFIER :**

# %%
from sklearn.tree import DecisionTreeClassifier

DTC_Algorithm = DecisionTreeClassifier()

DTC_Algorithm.fit(inputTRAIN,outputTRAIN)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# PREDICTING THE RESULTS :

# %%
DTC_Prediction = DTC_Algorithm.predict(inputTEST)

# %% [markdown]
# ACCURACY OF DecisionTreeClassifier :

# %%
SCORE_3 = accuracy_score(outputTEST,DTC_Prediction)*100
print(SCORE_3)
# Out:
# 90.0

# %% [markdown]
# WHAT ARE ERRORS IN TESTING (IF PRESET) :

# %%
for i in range (len(inputTEST)):
  if (DTC_Prediction[i]!=outputTEST[i]):
    print(i+1," ERROR !!")
    print("Predicted Result : ",DTC_Prediction[i],"\n","Actual Result : ",outputTEST[i])
# Out:
# 7  ERROR !!
# Predicted Result :  Iris-versicolor
#  Actual Result :  Iris-virginica
# 9  ERROR !!
# Predicted Result :  Iris-versicolor
#  Actual Result :  Iris-virginica
# 29  ERROR !!
# Predicted Result :  Iris-virginica
#  Actual Result :  Iris-versicolor

# %% [markdown]
# ---
# ---

# %% [markdown]
# # **COMPARISON OF MODELS :**

# %%
comparison = pd.DataFrame({'MODELS': ['LOGISTIC REGRESSION','SUPPORT VECTOR CLASSIFIER','DECISION TREE CLASSIFIER'],
                           'R2 SCORE': [SCORE_1, SCORE_2, SCORE_3]})

# %%
comparison
# Out:
#                       MODELS   R2 SCORE
# 0        LOGISTIC REGRESSION  93.333333
# 1  SUPPORT VECTOR CLASSIFIER  96.666667
# 2   DECISION TREE CLASSIFIER  90.000000

# %% [markdown]
# ---
#
# # ***THANK YOU !***
